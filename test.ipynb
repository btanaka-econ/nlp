# %%
# =============================================================================
# Python Script for AR-teXt Analysis of Bank of Japan Statements
#
# This script forecasts a single macroeconomic variable (CPI) using an
# Autoregressive model with eXogenous variables (AR-X), which is the
# correct approach for a single dependent variable.
#
# It compares a baseline AR model to a text-augmented AR-X model.
# =============================================================================

import pandas as pd
import numpy as np
import re
import sys

# --- NLP and Machine Learning ---
from gensim import corpora, models

# --- Time Series Analysis ---
from statsmodels.tsa.statespace.sarimax import SARIMAX
from sklearn.metrics import mean_squared_error

# --- Visualization ---
import matplotlib.pyplot as plt
import seaborn as sns

# --- Configuration ---
N_TOPICS = 10    # Number of topics to extract from the text
AR_LAGS = 3      # Number of autoregressive lags (the 'p' in AR(p))
TEST_SIZE = 12   # Number of months for the out-of-sample forecast test

def run_lda_analysis(corpus_path: str, n_topics: int):
    """
    Performs LDA using Gensim on the cleaned text corpus.
    """
    print("--- Step 1: Running LDA Analysis with Gensim ---")
    try:
        df_corpus = pd.read_csv(corpus_path)
    except FileNotFoundError:
        print(f"Error: The file '{corpus_path}' was not found. Please run your pre-processing script first.")
        return None

    processed_docs = df_corpus['cleaned_tokens'].apply(eval)
    dictionary = corpora.Dictionary(processed_docs)
    bow_corpus = [dictionary.doc2bow(doc) for doc in processed_docs]

    V = len(dictionary)
    alpha = 50 / n_topics
    eta = 200 / V

    print(f"Training LDA with K={n_topics}, alpha={alpha:.4f}, eta={eta:.4f}")
    lda_model = models.LdaModel(
        corpus=bow_corpus, id2word=dictionary, num_topics=n_topics,
        alpha=alpha, eta=eta, passes=15, iterations=400, random_state=42
    )

    print("\n--- Top Words for Each Topic ---")
    for idx, topic in lda_model.print_topics(-1):
        print(f"Topic #{idx}: {topic}")
    print("-" * 30)

    topic_distributions = []
    for doc_bow in bow_corpus:
        doc_topics = lda_model.get_document_topics(doc_bow, minimum_probability=0)
        topic_prob_dict = dict(doc_topics)
        topic_prob_vector = [topic_prob_dict.get(i, 0.0) for i in range(n_topics)]
        topic_distributions.append(topic_prob_vector)

    topic_cols = [f'topic_{i}' for i in range(n_topics)]
    df_topics = pd.DataFrame(topic_distributions, columns=topic_cols)
    df_topics['filename'] = df_corpus['filename']
    
    print("LDA analysis complete. Textual factors generated.")
    return df_topics

def prepare_data(topics_df: pd.DataFrame, macro_data_path: str):
    """
    Loads macroeconomic data, prepares it, and merges it with the topic data.
    """
    print("\n--- Step 2: Preparing and Merging Data ---")
    
    # --- Prepare Topic Data ---
    def extract_date_from_filename(filename):
        match = re.search(r'k(\d{2})(\d{2})(\d{2})', filename)
        if match:
            year, month, day = match.groups()
            return f"20{year}-{month}"
        return None

    topics_df['month'] = topics_df['filename'].apply(extract_date_from_filename)
    topics_df = topics_df.dropna(subset=['month'])
    
    monthly_topics = topics_df.groupby('month').mean(numeric_only=True)
    monthly_topics.index = pd.to_datetime(monthly_topics.index)

    # --- Prepare Macroeconomic Data ---
    try:
        df_macro = pd.read_csv(macro_data_path)
    except FileNotFoundError:
        print(f"Error: The file '{macro_data_path}' was not found.")
        return None
        
    date_col = 'date' if 'date' in df_macro.columns else 'data'
    if date_col not in df_macro.columns:
        print(f"Error: No date column named 'date' or 'data' found in '{macro_data_path}'.")
        return None

    df_macro[date_col] = pd.to_datetime(df_macro[date_col])
    df_macro = df_macro.set_index(date_col).sort_index()

    if not isinstance(df_macro.index, pd.DatetimeIndex):
        print("CRITICAL ERROR: The date column could not be converted to a proper DatetimeIndex.")
        return None
        
    macro_cols = df_macro.select_dtypes(include=np.number).columns.tolist()
    if not macro_cols:
        print(f"Error: No numeric data columns found in '{macro_data_path}'.")
        return None
    print(f"Detected macroeconomic variable(s): {macro_cols}")

    # Calculate Year-over-Year percentage change for the first macro variable
    primary_macro_var = macro_cols[0]
    df_macro[f'{primary_macro_var}_yoy'] = df_macro[primary_macro_var].pct_change(12) * 100
    
    df_macro = df_macro.dropna()

    print(f"Topic data available from {monthly_topics.index.min().strftime('%Y-%m')} to {monthly_topics.index.max().strftime('%Y-%m')}")
    print(f"Macro data available from {df_macro.index.min().strftime('%Y-%m')} to {df_macro.index.max().strftime('%Y-%m')}")

    # --- Merge DataFrames ---
    df_merged = df_macro.join(monthly_topics, how='left')
    topic_cols = [col for col in df_merged.columns if col.startswith('topic_')]
    
    print("\nFilling in empty months for textual data using forward fill...")
    df_merged[topic_cols] = df_merged[topic_cols].ffill()

    if df_merged[topic_cols].isnull().all().all():
        print("\n!!! CRITICAL ERROR: No overlap found between macro data dates and statement dates.")
        return None

    df_merged = df_merged.dropna()

    if df_merged.empty:
        print("\n!!! CRITICAL ERROR: The final dataset is empty after merging and cleaning.")
        return None
        
    print(f"Data preparation and merging complete. Final dataset shape: {df_merged.shape}")
    return df_merged

def run_arimax_analysis(df: pd.DataFrame):
    """
    Fits and compares the Baseline AR and text-augmented AR-X models using SARIMAX.
    """
    if df is None or df.empty:
        print("Cannot run analysis on empty data.")
        return

    print("\n--- Step 3: Running AR and AR-X Analysis ---")

    endog_var = [col for col in df.columns if col.endswith('_yoy')][0]
    print(f"Using '{endog_var}' as the dependent variable.")

    train_data = df.iloc[:-TEST_SIZE]
    test_data = df.iloc[-TEST_SIZE:]
    
    # --- Baseline AR Model ---
    print(f"\nFitting Baseline AR({AR_LAGS}) model...")
    # We use SARIMAX to fit an AR model: order=(p,d,q) where p=AR_LAGS, d=0 (data already differenced), q=0.
    model_baseline = SARIMAX(train_data[endog_var], order=(AR_LAGS, 0, 0))
    results_baseline = model_baseline.fit(disp=False)

    # --- Text-Augmented AR-X Model ---
    print(f"Fitting Text-Augmented AR-X({AR_LAGS}) model...")
    exog_vars = [col for col in df.columns if col.startswith('topic_')][:-1]
    model_text = SARIMAX(train_data[endog_var], exog=train_data[exog_vars], order=(AR_LAGS, 0, 0))
    results_text = model_text.fit(disp=False)

    # --- Forecasting and Evaluation ---
    print("\n--- Step 4: Forecasting and Evaluation ---")
    
    forecast_baseline = results_baseline.forecast(steps=TEST_SIZE)
    forecast_text = results_text.forecast(steps=TEST_SIZE, exog=test_data[exog_vars])

    rmse_baseline = np.sqrt(mean_squared_error(test_data[endog_var], forecast_baseline))
    rmse_text = np.sqrt(mean_squared_error(test_data[endog_var], forecast_text))

    print(f"\nForecasting Performance for {endog_var} (RMSE on test set of {TEST_SIZE} months):")
    print(f"  - Baseline AR:  {rmse_baseline:.4f}")
    print(f"  - AR-teXt:      {rmse_text:.4f}")

    if rmse_text < rmse_baseline:
        improvement = (rmse_baseline - rmse_text) / rmse_baseline * 100
        print(f"\nThe AR-teXt model improved the forecast, with an RMSE reduction of {improvement:.2f}%.")
    else:
        print(f"\nThe Baseline AR model performed better or equal for the forecast.")

    # --- Visualization ---
    fig, ax = plt.subplots(figsize=(14, 7))
    ax.plot(df.index, df[endog_var], label=f'Actual {endog_var}', color='black', linewidth=2)
    ax.plot(test_data.index, forecast_baseline, label=f'Baseline AR Forecast (RMSE: {rmse_baseline:.2f})', linestyle='--', color='blue')
    ax.plot(test_data.index, forecast_text, label=f'AR-teXt Forecast (RMSE: {rmse_text:.2f})', linestyle='--', color='red')
    
    ax.set_title(f'{endog_var} Forecast Comparison: Baseline AR vs. AR-teXt', fontsize=16)
    ax.set_ylabel(f'Year-over-Year Change (%)')
    ax.legend(fontsize=12)
    ax.axvspan(test_data.index[0], test_data.index[-1], color='gray', alpha=0.2, label='Test Period')
    plt.tight_layout()
    plt.savefig("forecast_comparison.png")
    print("\nForecast plot saved as 'forecast_comparison.png'")
    plt.show()

if __name__ == '__main__':
    print("====== Starting AR-teXt Replication (Gensim Version) ======")
    
    df_topics = run_lda_analysis("cleaned_english_corpus.csv", n_topics=N_TOPICS)
    
    if df_topics is not None:
        final_data = prepare_data(df_topics, "cpi.csv")
        run_arimax_analysis(df=final_data)
            
    print("\n====== Analysis Complete ======")
# Out:
# ====== Starting AR-teXt Replication (Gensim Version) ======
# --- Step 1: Running LDA Analysis with Gensim ---
# Training LDA with K=10, alpha=5.0000, eta=0.0641
#
# --- Top Words for Each Topic ---
# Topic #0: 0.032*"price" + 0.017*"polici" + 0.015*"increas" + 0.013*"econom" + 0.013*"moder" + 0.012*"purchas" + 0.010*"rise" + 0.010*"activ" + 0.009*"wage" + 0.009*"jgb"
# Topic #1: 0.037*"polici" + 0.020*"octob" + 0.016*"april" + 0.016*"deputi" + 0.015*"monetari" + 0.014*"thursday" + 0.014*"financ" + 0.012*"meet" + 0.010*"governor" + 0.010*"coordin"
# Topic #2: 0.023*"polici" + 0.015*"monetari" + 0.012*"price" + 0.008*"interest" + 0.005*"purchas" + 0.005*"financi" + 0.005*"expect" + 0.004*"bank" + 0.004*"rate" + 0.004*"econom"
# Topic #3: 0.024*"interest" + 0.020*"financi" + 0.016*"rate" + 0.015*"purchas" + 0.012*"monetari" + 0.012*"polici" + 0.012*"covid" + 0.011*"price" + 0.011*"yield" + 0.011*"impact"
# ...
