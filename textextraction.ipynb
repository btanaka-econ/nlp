# %%
from bs4 import BeautifulSoup
import csv
import requests
import sys
from urllib.request import Request, urlopen
import pdb

# %%
filename = 'fomc_url.csv'
# Checking the head of csv file
with open(filename, 'r') as f:
    file = csv.reader(f, delimiter=',')
    for i, row in enumerate(file):
        if i < 5:
            print(row)
        else:
            break
# Out:
# ['\ufeffdate', 'url', 'year', 'date', '']
# ['9/29/1998', 'https://www.federalreserve.gov/boarddocs/press/general/1998/19980929/default.htm', '1998', '0929', '']
# ['10/15/1998', 'https://www.federalreserve.gov/boarddocs/press/general/1998/19981015/', '1998', '1015', '']
# ['11/17/1998', 'https://www.federalreserve.gov/boarddocs/press/general/1998/19981117/default.htm', '1998', '1117', '']
# ['5/18/1999', 'https://www.federalreserve.gov/boarddocs/press/general/1999/19990518/', '1999', '0518', '']

# %%
url = None

with open(filename, 'r') as f:
    file = csv.reader(f, delimiter= ',')
    data_list = list(file)
    for i in range(1,189):
        url = data_list[i][1]
        # Use "url" as the link to web scrape
        req = Request(url, headers={'User-Agent': 'Mozilla/5.0'})
        page = urlopen(req)
        html = page.read().decode("utf-8")
        soup = BeautifulSoup(html, "html.parser")
        try:
            response = requests.get(url)
            response.raise_for_status()
        
            # 2. Parse the HTML using BeautifulSoup
            soup = BeautifulSoup(response.text, 'html.parser')
        
            # 3. Find all <p> (paragraph) tags
            # This searches the entire document and returns a list of all <p> tags found
            paragraphs = soup.find_all('p')

            print(f"Found {len(paragraphs)} paragraph tags. Scraping text...\n")
        
            output_filename = f"{data_list[i][2]}_{data_list[i][3]}.txt"
            with open(output_filename, 'w', encoding='utf-8') as outfile:
                outfile.write(f"Source URL: {url}\n")
            # 4. Loop through the list and print the text from each one
                for p in paragraphs:
            # .text strips all HTML tags and gives you just the plain text
                    outfile.write(p.text.strip())

        except requests.exceptions.RequestException as e:
            # This catches HTTP errors, connection errors, timeouts, etc.
            print(f"[ERROR] Skipping row {i}. Failed to retrieve URL.")
            print(f"      Problem Cell: (Row {i}, Column 1)")
            print(f"      URL: {url}")
            print(f"      Error details: {e}\n")
            # The loop will automatically continue to the next 'i'
        except Exception as e:
            # Catch any other unexpected error (e.g., file writing, bad data)
            print(f"[ERROR] An unexpected error occurred at row {i}.")
            print(f"      URL: {url}")
            print(f"      Error details: {e}\n")
            # The loop will automatically continue
# Out:
# Found 6 paragraph tags. Scraping text...
#
# Found 7 paragraph tags. Scraping text...
#
# Found 6 paragraph tags. Scraping text...
#
# Found 5 paragraph tags. Scraping text...
#
# Found 6 paragraph tags. Scraping text...
#
# Found 7 paragraph tags. Scraping text...
#
# Found 8 paragraph tags. Scraping text...
#
# Found 8 paragraph tags. Scraping text...
#
# Found 7 paragraph tags. Scraping text...
#
# Found 9 paragraph tags. Scraping text...
#
# Found 8 paragraph tags. Scraping text...
#
# Found 8 paragraph tags. Scraping text...
#
# Found 8 paragraph tags. Scraping text...
#
# Found 8 paragraph tags. Scraping text...
#
# Found 8 paragraph tags. Scraping text...
#
# Found 8 paragraph tags. Scraping text...
#
# Found 8 paragraph tags. Scraping text...
#
# Found 9 paragraph tags. Scraping text...
#
# Found 9 paragraph tags. Scraping text...
#
# Found 9 paragraph tags. Scraping text...
#
# Found 9 paragraph tags. Scraping text...
#
# Found 9 paragraph tags. Scraping text...
#
# ...

# %%
print(data_list[5][2],'_',data_list[5][3])
# Out:
# 1999 _ 0630

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 print(paragraphs)
#
# NameError: name 'paragraphs' is not defined
